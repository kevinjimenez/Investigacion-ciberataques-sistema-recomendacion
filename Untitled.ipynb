# %%
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# leer archivo de ratings por usuario y pelicula
df = pd.read_csv('/home/dev-11/Documents/kevin/Investigacion-ciberataques-sistema-recomendacion/datos-prueba/dataSets.data', sep='\t', names=['nombre','descripcion','rating','descripcion1'])
# listar 10 primeros registros del archivo de ratings
df.head(10)
# Out:
#                                               nombre  \
# 0   Attack: Agilent Feature Extraction CVE-2015-2092
# 1  Attack: Advantech WebAccess webvrpcs Service D...
# 2  Attack: Advantech WebAccess Node certUpdate Di...
# 3  Attack: Advantech WebAccess CVE-2017-16720 Act...
# 4  Attack: Advantech WebAccess webvrpcs Service B...
# 5      Attack: Adobe Photoshop Collada CVE-2012-2052
# 6               Attack: Adrenalin Player asx File BO
# 7  Attack: Adobe InDesign Server Arbitrary Script...
# 8   Attack: Advantech WebAccess Webvrpcs RCE Exploit
# 9  Attack: Advantech WebAccess Node certUpdate Di...
#
#                                          descripcion          rating  \
# 0  This signature detects attempts to exploit an ...  Severity: High
# 1  This signature detects attempts to cause a sta...  Severity: High
# 2  This signature detects attempts to cause a rem...  Severity: High
# 3  This signature detects the attempts to exploit...  Severity: High
# ...

# %%
len(df)
# Out:
# 6004
